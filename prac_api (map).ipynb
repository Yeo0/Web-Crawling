# %%
#영등포구 음식점 주소 모두 좌표로 변환
-파이썬 json내보내기 - 다시 불러와서 point 추출 저장
-여기서 request로 다시 읽기

# %%
import pandas as pd
import os
import sys
import urllib.request
import csv

client_id = "6omFMHOiwwWB57x69RFg"
client_secret = "ifUp5rwMNn"

df = pd.read_csv("download/address_data.csv")
address = df["소재지"]
address = address.fillna("0")

def addToPoint(add):
    client_id = "6omFMHOiwwWB57x69RFg"
    client_secret = "ifUp5rwMNn"

    if add == 0:
        print(0)
    else:
        encText=urllib.parse.quote(add)
        url = "https://openapi.naver.com/v1/map/geocode?query=" + encText
        request = urllib.request.Request(url)
        request.add_header("X-Naver-Client-Id",client_id)
        request.add_header("X-Naver-Client-Secret",client_secret)
       
        try:
            response = urllib.request.urlopen(request)
        except urllib.error.HTTPError:
            print(0)
        else:
            rescode = response.getcode()
            if(rescode==200):
                response_body = response.read()
                print(response_body.decode('utf-8'))
            else:
                print("Error Code:" + rescode)
    

for add in address:
    print(addToPoint(add))
   # with open('addPoint.csv', 'w', encoding='utf-8', newline='') as f:
    #    f.write(addToPoint(add))
# Out:
# {
#     "result": {
#         "total": 1,
#         "userquery": "서울특별시 영등포구 영중로10길 44",
#         "items": [
#             {
#                 "address": "서울특별시 영등포구 영중로10길 44",
#                 "addrdetail": {
#                     "country": "대한민국",
#                     "sido": "서울특별시",
#                     "sigugun": "영등포구",
#                     "dongmyun": "영중로10길",
#                     "ri": "",
#                     "rest": "44"
#                 },
#                 "isRoadAddress": true,
#                 "point": {
#                     "x": 126.9100033,
#                     "y": 37.5182959
#                 }
#             }
#         ]
#     }
# }
# None
# {
#     "result": {
#         "total": 1,
#         "userquery": "서울특별시 영등포구 대림로29길 43",
#         "items": [
#             {
#                 "address": "서울특별시 영등포구 대림로29길 43 영진빌딩",
#                 "addrdetail": {
#                     "country": "대한민국",
#                     "sido": "서울특별시",
# ...

# %%
def addToPoint(add):
    client_id = "6omFMHOiwwWB57x69RFg"
    client_secret = "ifUp5rwMNn"

    if add == 0:
        print(0)
    else:
        encText=urllib.parse.quote(add)
        url = "https://openapi.naver.com/v1/map/geocode?query=" + encText
        request = urllib.request.Request(url)
        request.add_header("X-Naver-Client-Id",client_id)
        request.add_header("X-Naver-Client-Secret",client_secret)
       
        try:
            response = urllib.request.urlopen(request)
        except urllib.error.HTTPError:
            print(0)
        else:
            rescode = response.getcode()
            if(rescode==200):
                response_body = response.read()
                response_body=response_body["result"]
                print(response_body.decode('utf-8'))
            else:
                print("Error Code:" + rescode)
    
    
addToPoint(address[1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-540caa8d9f4a> in <module>()
#      26
#      27
# ---> 28 addToPoint(address[1])
#
# <ipython-input-37-540caa8d9f4a> in addToPoint(add)
#      20             if(rescode==200):
#      21                 response_body = response.read()
# ---> 22                 response_body=response_body["result"]
#      23                 print(response_body.decode('utf-8'))
#      24             else:
#
# TypeError: byte indices must be integers or slices, not str

# %%
address[0]
address[2]=="N"
print(0)
# Out:
# 0

# %%
encText = urllib.parse.quote("여의대방로35길 30")
url = "https://openapi.naver.com/v1/map/geocode?query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/map/geocode.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-32-f604c7fe1989> in <module>()
#       5 request.add_header("X-Naver-Client-Id",client_id)
#       6 request.add_header("X-Naver-Client-Secret",client_secret)
# ----> 7 response = urllib.request.urlopen(request)
#       8 rescode = response.getcode()
#       9 if(rescode==200):
#
# /anaconda3/lib/python3.6/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# /anaconda3/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     530         for processor in self.process_response.get(protocol, []):
#     531             meth = getattr(processor, meth_name)
# --> 532             response = meth(req, response)
# ...
