# %%
import requests
from bs4 import BeautifulSoup

url="http://openapi.seoul.go.kr:8088/5a6e745152776f6f3130307657484d4b/xml/octastatapi10043/3/20/2016/용산구/"
r=requests.get(url).text

#xml분석
soup=BeautifulSoup(r, 'html.parser')
names=['gigan','jachigu','dong','sedae','gye_1','sedaedangingu']

#print(soup.select("row")[1])

for i in range(len(names)):
    for name in names:
        sels=soup.select("row {}".format(name))[i]
        for sel in sels:
            print(sel.string)
    print("---")
    i+=1
    
    #print(soup.select("row gigan"))

#for i in range(18):
#    for name in names:
#        finds=soup.find(name)
#        print(find.string)
#        print("---")
            #print(finds.string)

# %%
#주소->좌표
import os
import sys
import urllib.request
client_id = "6omFMHOiwwWB57x69RFg"
client_secret = "ifUp5rwMNn"
encText = urllib.parse.quote("능동로 120")
url = "https://openapi.naver.com/v1/map/geocode?query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/map/geocode.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
#     "result": {
#         "total": 3,
#         "userquery": "능동로 120",
#         "items": [
#             {
#                 "address": "서울특별시 광진구 능동로 120 건국대학교",
#                 "addrdetail": {
#                     "country": "대한민국",
#                     "sido": "서울특별시",
#                     "sigugun": "광진구",
#                     "dongmyun": "능동로",
#                     "ri": "",
#                     "rest": "120 건국대학교"
#                 },
#                 "isRoadAddress": true,
#                 "point": {
#                     "x": 127.0759546,
#                     "y": 37.5438883
#                 }
#             },
#             {
#                 "address": "경상남도 김해시 능동로 119 부영아파트상가",
#                 "addrdetail": {
#                     "country": "대한민국",
#                     "sido": "경상남도",
#                     "sigugun": "김해시",
#                     "dongmyun": "능동로",
#                     "ri": "",
#                     "rest": "119 부영아파트상가"
# ...

# %%
#좌표->주소
import os
import sys
import urllib.request
client_id = "6omFMHOiwwWB57x69RFg"
client_secret = "ifUp5rwMNn"
encText = urllib.parse.quote("127.0759546,37.5438883")
url = "https://openapi.naver.com/v1/map/reversegeocode?query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/map/geocode.xml?query=" + encText # xml 결과

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
#     "result": {
#         "total": 3,
#         "userquery": "127.0759546,37.5438883",
#         "items": [
#             {
#                 "address": "서울특별시 광진구 화양동",
#                 "addrdetail": {
#                     "country": "대한민국",
#                     "sido": "서울특별시",
#                     "sigugun": "광진구",
#                     "dongmyun": "화양동",
#                     "ri": "",
#                     "rest": ""
#                 },
#                 "isAdmAddress": false,
#                 "isRoadAddress": false,
#                 "point": {
#                     "x": 127.0713515,
#                     "y": 37.5464594
#                 }
#             },
#             {
#                 "address": "서울특별시 광진구 화양동 393-1",
#                 "addrdetail": {
#                     "country": "대한민국",
#                     "sido": "서울특별시",
#                     "sigugun": "광진구",
#                     "dongmyun": "화양동",
#                     "ri": "",
# ...

# %%
#네이버 지도 이미지 출력
import os
import sys
import urllib.request
client_id = "6omFMHOiwwWB57x69RFg"
client_secret = "ifUp5rwMNn"
konkuk="127.0759546,37.5438883"
site="https://yeo0.github.io"
encText = urllib.parse.quote("능동로120")
url = "https://openapi.naver.com/v1/map/staticmap.bin?clientId="+client_id +"&url="+site+"&center="+konkuk+"&level="+"1"+"&w="+"200"+"&h="+"200"+"&baselayer="+"default"+"&format="+"png" 
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-16'))
else:
    print("Error Code:" + rescode)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-38-67735fb4ca96> in <module>()
#      16 if(rescode==200):
#      17     response_body = response.read()
# ---> 18     print(response_body.decode('utf-16'))
#      19 else:
#      20     print("Error Code:" + rescode)
#
# UnicodeDecodeError: 'utf-16-le' codec can't decode bytes in position 94-95: illegal UTF-16 surrogate
